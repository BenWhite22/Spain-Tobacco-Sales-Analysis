# %% [markdown]
# <h5>In this notebook I will create a regression model for predicting tobacco sales in 2017 based on the analysis in </h5>

# %%
#Import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
palette = sns.color_palette()

pd.options.mode.chained_assignment = None

#Import model and pre-processing packages
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import TimeSeriesSplit

#Change Panadas options so we can see all columns
pd.set_option('display.max_columns', 500)

# %%
sales_df = pd.read_csv('/Users/benaw/Documents/Personal/Job Applications 2023/.ipynb_checkpoints/Tobacco_Sales.csv', encoding='unicode_escape', parse_dates=True, dayfirst=True, index_col=0)

# %% [markdown]
# <h2>Feature Manipultaion</h2>

# %%
#Rename total sales column
new_cols={'Total':'Total Sales'}

full_df = sales_df.rename(columns=new_cols)

# %%
#Create features for time series information
full_df['Year'] = full_df.index.year
full_df['Month'] = full_df.index.month

# %%
#Function for creating 12 and 24 month lag feature for sales
def lags(df, i):
    df['Lag'] = df[i].shift(12)
    df['Lag1'] = df[i].shift(24)

# %%
#This is the df we will store our predictions in
predictions = pd.DataFrame(columns=full_df.columns[:-2])

#These are the features we will use for training our models
features = ['Year', 'Month', 'Lag']

"""
The code below will loop through the columns for each province, create 12 month and 24 month lag features and create two 
dataframes - a training df for dates between 2013 and 2016 which will be used for training the model, and a df for 2017 
predictions. It will then make and train an XGBoost model and then make preditions for 2017; storing them in the 'preditions' 
dataframe defined above.
"""
for i in full_df.columns[:-2]:
    #Create lag feature for the province
    lags(full_df, i)
    
    #Split into training df (before 2017) and prediction df (2017)
    pred_df = full_df[full_df.index >= '2017-01-01']
    train_df = full_df[full_df.index < '2017-01-01']
    
    #Create dfs for training features and target feature 
    train_X = train_df[features]
    train_y = train_df[i]

    #Create XGBoost model
    reg = xgb.XGBRegressor(n_estimators=800, 
                           learning_rate=0.01, 
                           booster='gbtree', 
                           early_stopping_rounds=50, 
                           max_depth=3)

    #Fit the model 
    reg.fit(train_X, train_y, 
            eval_set=[(train_X, train_y)], 
            verbose=100)
    
    #Make preditions for 2017
    predictions[i] = reg.predict(pred_df[features])

#Date index for predictions df
predictions.index = pd.date_range('01/01/2017', '12/01/2017', freq='MS')
# Out:
# [0]	validation_0-rmse:195058157.32232
# [100]	validation_0-rmse:75103484.75695
# [200]	validation_0-rmse:30891908.29021
# [300]	validation_0-rmse:14799915.37153
# [400]	validation_0-rmse:9367458.80642
# [500]	validation_0-rmse:7559240.70968
# [600]	validation_0-rmse:6712531.45197
# [700]	validation_0-rmse:6178486.50321
# [799]	validation_0-rmse:5747228.09551
# [0]	validation_0-rmse:1256435.62558
# [100]	validation_0-rmse:489483.86182
# [200]	validation_0-rmse:221095.31061
# [300]	validation_0-rmse:133030.80623
# [400]	validation_0-rmse:106192.01881
# [500]	validation_0-rmse:96892.26229
# [600]	validation_0-rmse:91808.53527
# [700]	validation_0-rmse:88108.04898
# [799]	validation_0-rmse:85427.21870
# [0]	validation_0-rmse:1721084.97119
# [100]	validation_0-rmse:659912.42215
# [200]	validation_0-rmse:270530.52852
# [300]	validation_0-rmse:129279.42456
# [400]	validation_0-rmse:79366.46855
# [799]	validation_0-rmse:77057.05641
# [0]	validation_0-rmse:3050810.65760
# [100]	validation_0-rmse:1222925.65159
# [200]	validation_0-rmse:535965.36330
# [300]	validation_0-rmse:270394.13068
# [400]	validation_0-rmse:175315.78626
# [500]	validation_0-rmse:141060.48899
# [600]	validation_0-rmse:116830.24446
# [700]	validation_0-rmse:98512.79701
# [799]	validation_0-rmse:85694.22669
# [0]	validation_0-rmse:2594246.65367
# [100]	validation_0-rmse:1028332.16876
# [200]	validation_0-rmse:438110.87968
# [300]	validation_0-rmse:211589.64468
# [400]	validation_0-rmse:128798.28538
# [500]	validation_0-rmse:98784.31130
# [600]	validation_0-rmse:83590.60337
# [700]	validation_0-rmse:75407.15277
# [799]	validation_0-rmse:69185.59587
# [0]	validation_0-rmse:2294069.31367
# [100]	validation_0-rmse:880291.18576
# [200]	validation_0-rmse:362261.58515
# [300]	validation_0-rmse:177584.84481
# [400]	validation_0-rmse:113319.87982
# [500]	validation_0-rmse:90357.81585
# [600]	validation_0-rmse:82075.01801
# [700]	validation_0-rmse:75560.72499
# [799]	validation_0-rmse:70274.07402
# [0]	validation_0-rmse:2719243.58449
# [100]	validation_0-rmse:1036292.29182
# [200]	validation_0-rmse:422166.16885
# [300]	validation_0-rmse:211748.74934
# [400]	validation_0-rmse:142836.24787
# [500]	validation_0-rmse:117282.42844
# [600]	validation_0-rmse:104634.44354
# [700]	validation_0-rmse:94257.37704
# [799]	validation_0-rmse:88733.25412
# [0]	validation_0-rmse:4722819.22454
# [100]	validation_0-rmse:1808921.77998
# [200]	validation_0-rmse:749347.91086
# [300]	validation_0-rmse:363785.16793
# [400]	validation_0-rmse:244651.43941
# [500]	validation_0-rmse:203468.26610
# [600]	validation_0-rmse:179470.73755
# [700]	validation_0-rmse:158521.10950
# [799]	validation_0-rmse:145423.52522
# [0]	validation_0-rmse:1000302.85436
# [100]	validation_0-rmse:394301.85059
# [200]	validation_0-rmse:172557.99812
# [300]	validation_0-rmse:93494.20981
# [400]	validation_0-rmse:60447.31995
# [500]	validation_0-rmse:47266.45943
# [600]	validation_0-rmse:41953.95672
# [700]	validation_0-rmse:38696.41132
# [799]	validation_0-rmse:36498.52510
# [0]	validation_0-rmse:8719530.29671
# [100]	validation_0-rmse:3706635.93045
# [200]	validation_0-rmse:1697604.32899
# [300]	validation_0-rmse:912467.76366
# [400]	validation_0-rmse:619302.16293
# [500]	validation_0-rmse:436439.27992
# [600]	validation_0-rmse:330980.18621
# [700]	validation_0-rmse:270688.89036
# [799]	validation_0-rmse:229957.46696
# [0]	validation_0-rmse:3926603.63538
# [100]	validation_0-rmse:1498508.34447
# [200]	validation_0-rmse:610959.90408
# [300]	validation_0-rmse:297399.08544
# [400]	validation_0-rmse:194412.84920
# [500]	validation_0-rmse:153632.03291
# [600]	validation_0-rmse:132661.15914
# [700]	validation_0-rmse:118637.38822
# [799]	validation_0-rmse:102673.98251
# [0]	validation_0-rmse:1052189.34460
# [100]	validation_0-rmse:405405.47383
# [500]	validation_0-rmse:60005.88657
# [600]	validation_0-rmse:52735.40460
# [700]	validation_0-rmse:47511.21676
# [799]	validation_0-rmse:43647.87984
# [0]	validation_0-rmse:25489842.86308
# [100]	validation_0-rmse:9702586.36261
# [200]	validation_0-rmse:3920125.11584
# [300]	validation_0-rmse:1956501.25664
# [400]	validation_0-rmse:1366521.00267
# [500]	validation_0-rmse:1158200.27951
# [600]	validation_0-rmse:1048582.36520
# [700]	validation_0-rmse:949673.31403
# [799]	validation_0-rmse:852691.13453
# [0]	validation_0-rmse:6431932.07091
# [100]	validation_0-rmse:2533398.68327
# [200]	validation_0-rmse:1072308.53984
# [300]	validation_0-rmse:537271.08114
# [400]	validation_0-rmse:357481.64859
# [500]	validation_0-rmse:297520.51874
# [600]	validation_0-rmse:241973.98678
# [700]	validation_0-rmse:206140.28135
# [799]	validation_0-rmse:176471.10419
# [0]	validation_0-rmse:6837682.23792
# [100]	validation_0-rmse:2611271.39615
# [200]	validation_0-rmse:1066016.56279
# [300]	validation_0-rmse:516067.62872
# [400]	validation_0-rmse:341974.30934
# [500]	validation_0-rmse:286417.87646
# [600]	validation_0-rmse:249000.53596
# [700]	validation_0-rmse:226554.10836
# [799]	validation_0-rmse:209583.79571
# [0]	validation_0-rmse:4128532.73404
# [100]	validation_0-rmse:1625209.34414
# [200]	validation_0-rmse:704457.27076
# [300]	validation_0-rmse:385562.94489
# [400]	validation_0-rmse:283682.36062
# [500]	validation_0-rmse:238991.56753
# [600]	validation_0-rmse:212394.59536
# [700]	validation_0-rmse:197399.35454
# [799]	validation_0-rmse:182859.53658
# [0]	validation_0-rmse:1328349.02299
# [100]	validation_0-rmse:512342.88235
# [200]	validation_0-rmse:215476.49017
# [300]	validation_0-rmse:104994.45981
# [400]	validation_0-rmse:63494.86569
# [500]	validation_0-rmse:48647.20849
# [600]	validation_0-rmse:42201.95935
# [700]	validation_0-rmse:36657.85516
# [799]	validation_0-rmse:33425.70934
# [0]	validation_0-rmse:4874887.89195
# [100]	validation_0-rmse:1863312.89718
# [200]	validation_0-rmse:770543.80707
# [300]	validation_0-rmse:381141.97468
# [400]	validation_0-rmse:246214.38386
# [500]	validation_0-rmse:192762.76512
# [600]	validation_0-rmse:162051.15495
# [700]	validation_0-rmse:145006.38717
# [799]	validation_0-rmse:132505.48394
# [0]	validation_0-rmse:762028.37163
# [100]	validation_0-rmse:297948.58850
# [200]	validation_0-rmse:131574.32832
# [300]	validation_0-rmse:74012.19265
# [400]	validation_0-rmse:53985.51641
# [500]	validation_0-rmse:44741.00857
# [600]	validation_0-rmse:41546.58975
# [700]	validation_0-rmse:37857.07089
# [799]	validation_0-rmse:35192.84721
# [0]	validation_0-rmse:3583766.11199
# [100]	validation_0-rmse:1384225.42244
# [200]	validation_0-rmse:579384.97908
# [300]	validation_0-rmse:273086.27975
# [400]	validation_0-rmse:160003.06074
# [500]	validation_0-rmse:117878.62978
# [600]	validation_0-rmse:98276.20643
# [700]	validation_0-rmse:86607.27161
# [799]	validation_0-rmse:78604.65108
# [0]	validation_0-rmse:1390229.06260
# [100]	validation_0-rmse:548101.89597
# [200]	validation_0-rmse:250815.01315
# [300]	validation_0-rmse:149036.10055
# [400]	validation_0-rmse:113124.02873
# [500]	validation_0-rmse:98736.25877
# [600]	validation_0-rmse:91633.85774
# [700]	validation_0-rmse:86630.88980
# [799]	validation_0-rmse:81630.43733
# [0]	validation_0-rmse:2715766.50923
# [100]	validation_0-rmse:1062570.91252
# [200]	validation_0-rmse:450479.75608
# [300]	validation_0-rmse:220423.78703
# [400]	validation_0-rmse:139885.26565
# [500]	validation_0-rmse:108920.95345
# [600]	validation_0-rmse:93630.03496
# [700]	validation_0-rmse:83720.16124
# [799]	validation_0-rmse:75963.96403
# [0]	validation_0-rmse:642765.83635
# [100]	validation_0-rmse:254644.07625
# [200]	validation_0-rmse:110374.85945
# [300]	validation_0-rmse:57876.26841
# [400]	validation_0-rmse:39544.80904
# [500]	validation_0-rmse:33689.35057
# [600]	validation_0-rmse:30794.63696
# [700]	validation_0-rmse:28223.34440
# [799]	validation_0-rmse:26375.67039
# [0]	validation_0-rmse:5400756.01571
# [100]	validation_0-rmse:2060131.59844
# [200]	validation_0-rmse:838746.09756
# [300]	validation_0-rmse:419485.65838
# [400]	validation_0-rmse:279658.64368
# [500]	validation_0-rmse:222142.39611
# [600]	validation_0-rmse:193302.19197
# [700]	validation_0-rmse:170440.31434
# [799]	validation_0-rmse:148030.70458
# [0]	validation_0-rmse:400951.84743
# [100]	validation_0-rmse:158252.19468
# [200]	validation_0-rmse:67918.11302
# [300]	validation_0-rmse:35027.73145
# [400]	validation_0-rmse:23150.49842
# [500]	validation_0-rmse:19094.65043
# [600]	validation_0-rmse:16973.47758
# [700]	validation_0-rmse:15905.34046
# [799]	validation_0-rmse:15051.86998
# [0]	validation_0-rmse:3867823.81808
# [100]	validation_0-rmse:1563610.59080
# [200]	validation_0-rmse:681964.52907
# [300]	validation_0-rmse:351723.06069
# [400]	validation_0-rmse:226227.98230
# [500]	validation_0-rmse:176408.97649
# [600]	validation_0-rmse:154088.51041
# [700]	validation_0-rmse:139059.80587
# [799]	validation_0-rmse:128646.59535
# [0]	validation_0-rmse:635573.55880
# [100]	validation_0-rmse:249809.66515
# [200]	validation_0-rmse:107383.30949
# [300]	validation_0-rmse:57095.07981
# [400]	validation_0-rmse:40267.07752
# [500]	validation_0-rmse:30372.93648
# [600]	validation_0-rmse:24833.50180
# [700]	validation_0-rmse:21465.83257
# [799]	validation_0-rmse:18600.00821
# [0]	validation_0-rmse:2895682.50582
# [100]	validation_0-rmse:1112573.55330
# [200]	validation_0-rmse:461089.24022
# [300]	validation_0-rmse:231124.58751
# [400]	validation_0-rmse:157171.01450
# [500]	validation_0-rmse:130892.10707
# [600]	validation_0-rmse:117990.95191
# [700]	validation_0-rmse:108485.27325
# [799]	validation_0-rmse:103549.79793
# [0]	validation_0-rmse:10985929.18561
# [100]	validation_0-rmse:4178630.61081
# [200]	validation_0-rmse:1686300.89449
# [300]	validation_0-rmse:800312.26627
# [400]	validation_0-rmse:514605.54583
# [500]	validation_0-rmse:426819.10825
# [600]	validation_0-rmse:382644.92773
# [700]	validation_0-rmse:351079.41070
# [799]	validation_0-rmse:317211.21391
# [0]	validation_0-rmse:2130543.87273
# [100]	validation_0-rmse:818100.35362
# [200]	validation_0-rmse:347138.40722
# [300]	validation_0-rmse:183894.39674
# [400]	validation_0-rmse:129797.25238
# [500]	validation_0-rmse:111777.30190
# [600]	validation_0-rmse:104027.72734
# [700]	validation_0-rmse:99950.21915
# [799]	validation_0-rmse:97287.72084
# [0]	validation_0-rmse:4640182.59797
# [100]	validation_0-rmse:1769439.85503
# [200]	validation_0-rmse:724221.16947
# [300]	validation_0-rmse:373184.19043
# [400]	validation_0-rmse:264771.62159
# [500]	validation_0-rmse:224478.55410
# [600]	validation_0-rmse:206848.57437
# [700]	validation_0-rmse:196204.12245
# [799]	validation_0-rmse:182472.03149
# [0]	validation_0-rmse:786902.58230
# [100]	validation_0-rmse:308334.81583
# [200]	validation_0-rmse:132518.69797
# [300]	validation_0-rmse:68095.91807
# [400]	validation_0-rmse:43827.40693
# [500]	validation_0-rmse:34095.30120
# [600]	validation_0-rmse:28877.89960
# [700]	validation_0-rmse:25641.19933
# [799]	validation_0-rmse:23479.47241
# [0]	validation_0-rmse:4307239.97588
# [100]	validation_0-rmse:1641722.47247
# [200]	validation_0-rmse:674616.31786
# [300]	validation_0-rmse:342985.90954
# [400]	validation_0-rmse:231029.69215
# [500]	validation_0-rmse:189325.52685
# [600]	validation_0-rmse:179473.69147
# [700]	validation_0-rmse:166539.09213
# [799]	validation_0-rmse:153851.88592
# [0]	validation_0-rmse:452774.46750
# [100]	validation_0-rmse:173485.49975
# [200]	validation_0-rmse:71769.94340
# [300]	validation_0-rmse:35620.57443
# [400]	validation_0-rmse:22383.99514
# [500]	validation_0-rmse:17487.54958
# [600]	validation_0-rmse:15215.44645
# [700]	validation_0-rmse:13716.01297
# [799]	validation_0-rmse:12640.59771
# [0]	validation_0-rmse:362724.01268
# [100]	validation_0-rmse:140470.45915
# [200]	validation_0-rmse:61301.62062
# [300]	validation_0-rmse:35482.74023
# [400]	validation_0-rmse:27192.54328
# [500]	validation_0-rmse:23978.20047
# [600]	validation_0-rmse:22164.42590
# [700]	validation_0-rmse:20842.85346
# [799]	validation_0-rmse:19798.55493
# [0]	validation_0-rmse:1994.27130
# [100]	validation_0-rmse:745.17064
# [200]	validation_0-rmse:278.43865
# [300]	validation_0-rmse:104.04531
# [400]	validation_0-rmse:38.89107
# [500]	validation_0-rmse:14.56896
# [600]	validation_0-rmse:5.53196
# [700]	validation_0-rmse:2.13542
# [799]	validation_0-rmse:0.84004

# %%
plt.figure(figsize=(15,5))
full_df['Total Sales'].plot(label='Actual Sales')
predictions['Total Sales'].plot(label='Model Predictions')
plt.title('Tobacco Sales 2013-2016 vs 2017 Model Predictions')
plt.ylabel('Tobacco Sales')
plt.legend()
plt.show()
